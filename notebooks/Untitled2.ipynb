# %%
from packaging import version

import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats
import tensorboard as tb

# %%
experiment_id = "../multirun_BM_/benchm-2/_2025-07-09_21-40/loss.delta=1,loss=huber,model=unet/events.out.tfevents.1752135489.dnagpu002.1401826.4"
experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
df = experiment.get_scalars()
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 experiment_id = "../multirun_BM_/benchm-2/_2025-07-09_21-40/loss.delta=1,loss=huber,model=unet/events.out.tfevents.1752135489.dnagpu002.1401826.4"
# ----> 2 experiment = tb.data.experimental.ExperimentFromDev(experiment_id)
#       3 df = experiment.get_scalars()
#       4 df
#
# AttributeError: module 'tensorboard' has no attribute 'data'

# %%
major_ver, minor_ver, _ = version.parse(tb.__version__).release
assert major_ver >= 2 and minor_ver >= 3, \
    "This notebook requires TensorBoard 2.3 or later."
print("TensorBoard version: ", tb.__version__)
# Out:
# TensorBoard version:  2.18.0
