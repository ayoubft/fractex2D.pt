# %%
import glob

# %%
ovas23_c = (
    sum(1 for line in open('../data/ovaskainen23_/train/list.txt') if line.strip()),
    sum(1 for line in open('../data/ovaskainen23_/valid/list.txt') if line.strip()),
    sum(1 for line in open('../data/ovaskainen23_/test/list.txt') if line.strip()),
)
ovas23_c
# Out:
# (2808, 966, 671)

# %%
geocrack_c = (
    sum(1 for line in open('../data/GeoCrack_/train/list.txt') if line.strip()),
    sum(1 for line in open('../data/GeoCrack_/valid/list.txt') if line.strip()),
    sum(1 for line in open('../data/GeoCrack_/test/list.txt') if line.strip()),
)
geocrack_c # 6079, 3039, 3040
# Out:
# (2808, 966, 671)

# %% [markdown]
# ovas23_old = (7484, 16645, 4917)

# %%
samsu19_c = (
    sum(1 for line in open('../data/samsu19/train/list.txt') if line.strip()),
    sum(1 for line in open('../data/samsu19/valid/list.txt') if line.strip()),
    sum(1 for line in open('../data/samsu19/test/list.txt') if line.strip()),
)
samsu19_c
# Out:
# (642, 228, 229)

# %%
matteo21_c = (
    len(glob.glob('../data/matteo21/train/image/*')),
    len(glob.glob('../data/matteo21/valid/image/*')),
    len(glob.glob('../data/matteo21/test/image/*')),
)
matteo21_c
# Out:
# (2174, 323, 912)

# %%
train_c, valid_c, test_c = (sum(x) for x in zip(ovas23_c, matteo21_c, samsu19_c))
train_c, valid_c, test_c
# Out:
# (5624, 1517, 1812)

# %%
total = sum((train_c, valid_c, test_c))
train_p, valid_p, test_p = (x/total*100 for x in (train_c, valid_c, test_c))
train_p, valid_p, test_p
# Out:
# (62.816932871663134, 16.944041103540712, 20.239026024796157)

# %% [markdown]
# 8953
